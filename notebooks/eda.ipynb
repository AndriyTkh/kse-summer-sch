# %% [markdown]
# # EDA — air-raid alerts
# Sanity-check raw sources before the pipeline. Confirm: oblast codelist, Kyiv->UTC + DST, `model` value set (threat map), positive rate (imbalance), war non-stationarity (2022 vs 2025).

# %%
import sys; sys.path.append('..')
import pandas as pd
from src import config, loaders, threat_map
config.DATA_DIR
# Out:
# WindowsPath('C:/Users/andri/Documents/WebDev/kse-summer-sch/data')
